# %%
import pandas as pd
path= 'Original_csv.csv'
df= pd.read_csv(path)
# df

# %%
# 1. Drop unnecessary columns

df_temp = df.drop(columns=['class_id', 'rad_id', 'x_min', 'y_min', 'x_max', 'y_max'])

# 2–4. Group by image_id and combine unique class names (case-insensitive)
df_new = (
    df_temp.assign(class_name_lower=df_temp['class_name'].str.lower())
           .groupby(['image_id'])
           .agg({
                'class_name': lambda x: ', '.join(
                    sorted({name.lower(): name for name in x}.values())
                )
           })
           .reset_index()
)

# %%
df_new['label'] = df_new['class_name'].apply(
    lambda x: "Normal" if x.strip().lower() == "no finding" else "Abnormal"
)
df_new
# Out:
#                                image_id  \
# 0      000434271f63a053c4128a0ba6352c7f
# 1      00053190460d56c53cc3e57321387478
# 2      0005e8e3701dfb1dd93d53e2ff537b6e
# 3      0006e0a85696f6bb578e84fafa9a5607
# 4      0007d316f756b3fa0baea2ff514ce945
# ...                                 ...
# 14995  ffe6f9fe648a7ec29a50feb92d6c15a4
# 14996  ffea246f04196af602c7dc123e5e48fc
# 14997  ffeffc54594debf3716d6fcd2402a99f
# 14998  fff0f82159f9083f3dd1f8967fc54f6a
# 14999  fff2025e3c1d6970a8a6ee0404ac6940
#
#                                               class_name     label
# 0                                             No finding    Normal
# 1                                             No finding    Normal
# 2      Consolidation, Infiltration, Lung Opacity, Nod...  Abnormal
# 3                                             No finding    Normal
# 4      Aortic enlargement, Cardiomegaly, ILD, Pleural...  Abnormal
# ...                                                  ...       ...
# 14995     Aortic enlargement, Cardiomegaly, Other lesion  Abnormal
# 14996                                         No finding    Normal
# 14997                                 Aortic enlargement  Abnormal
# 14998                                         No finding    Normal
# 14999                                         No finding    Normal
#
# [15000 rows x 3 columns]

# %%
import numpy as np
df_new[df_new['label']=='Abnormal']
# Out:
#                                image_id  \
# 2      0005e8e3701dfb1dd93d53e2ff537b6e
# 4      0007d316f756b3fa0baea2ff514ce945
# 6      000d68e42b71d3eac10ccc077aba07c1
# 7      00150343289f317a0ad5629d5b7d9ef9
# 9      001d127bad87592efe45a5c7678f8b8d
# ...                                 ...
# 14986  ff924bcbd38f123aec723aa7040d7e43
# 14987  ffb5d0b005261ed350f7a08c06613a34
# 14991  ffceb71a80efba3b83c88e11f4b9694b
# 14995  ffe6f9fe648a7ec29a50feb92d6c15a4
# 14997  ffeffc54594debf3716d6fcd2402a99f
#
#                                               class_name     label
# 2      Consolidation, Infiltration, Lung Opacity, Nod...  Abnormal
# 4      Aortic enlargement, Cardiomegaly, ILD, Pleural...  Abnormal
# 6      Aortic enlargement, Lung Opacity, Other lesion...  Abnormal
# 7      Aortic enlargement, Cardiomegaly, Lung Opacity...  Abnormal
# 9                      Calcification, Pulmonary fibrosis  Abnormal
# ...                                                  ...       ...
# 14986  Atelectasis, Consolidation, Lung Opacity, Pleu...  Abnormal
# 14987                   Aortic enlargement, Cardiomegaly  Abnormal
# 14991                   Cardiomegaly, Pulmonary fibrosis  Abnormal
# 14995     Aortic enlargement, Cardiomegaly, Other lesion  Abnormal
# 14997                                 Aortic enlargement  Abnormal
#
# [4394 rows x 3 columns]

# %% [markdown]
# # selected dataset

# %%
# Separate Normal and Abnormal cases
df_normal = df_new[df_new['label'] == "Normal"]
df_abnormal = df_new[df_new['label'] == "Abnormal"]

# Randomly select 4500 Normal rows
df_normal_sampled = df_normal.sample(n=4500, random_state=42)

# Combine all Abnormal + sampled Normal
df_final = pd.concat([df_normal_sampled, df_abnormal], ignore_index=True)

# Shuffle the final dataset
df_final = df_final.sample(frac=1, random_state=42).reset_index(drop=True)

# Add ".dicom" extension to image_id column
df_final['image_id'] = df_final['image_id'].astype(str) + ".dicom"

# %%
df_final
# Out:
#                                     image_id  \
# 0     1245f853816564c0ee3f1b9e93521ff0.dicom
# 1     19d8fca6a7a5bbc35dc669ef9406ba99.dicom
# 2     52fe2f01573413223b1f7edee17de341.dicom
# 3     59ab79bb1fce73184425a6572169999e.dicom
# 4     75b4afff533ef3bbced8fdae06ac6511.dicom
# ...                                      ...
# 8889  47322c3b3510df3e395773eca7e06dc8.dicom
# 8890  285cdfec4d725d327266833adf3ba9d5.dicom
# 8891  332f505a735ca0961e7128fc0f166a5c.dicom
# 8892  b6b5e7a80a8caf01b7721d63ae0551be.dicom
# 8893  a24f6e745dea4cfb8c3a31aa084650f7.dicom
#
#                                              class_name     label
# 0     Aortic enlargement, Infiltration, Other lesion...  Abnormal
# 1                                            No finding    Normal
# 2                                    Pulmonary fibrosis  Abnormal
# 3                                            No finding    Normal
# 4                                            No finding    Normal
# ...                                                 ...       ...
# 8889                         Cardiomegaly, Other lesion  Abnormal
# 8890                   Aortic enlargement, Cardiomegaly  Abnormal
# 8891                   Aortic enlargement, Cardiomegaly  Abnormal
# 8892                                         No finding    Normal
# 8893           Consolidation, Lung Opacity, Nodule/Mass  Abnormal
#
# [8894 rows x 3 columns]

# %%
df_final.to_csv('/home/jupyter-nafisha/X-ray/CSVs/Selected_all.csv', index=False)

# %% [markdown]
# # train, val and test split

# %%
import pandas as pd
df = pd.read_csv("/home/jupyter-nafisha/X-ray/CSVs/Selected_all.csv")

# %%
# Split into normal and abnormal
df_normal = df[df["label"] == "Normal"]
df_abnormal = df[df["label"] == "Abnormal"]

print("Normal:", len(df_normal))
print("Abnormal:", len(df_abnormal))
# Out:
# Normal: 4500
# Abnormal: 4394

# %%
# -------------------------------
# Normal splits
# -------------------------------
normal_train  = df_normal.sample(n=3150, random_state=42)
remaining_normal = df_normal.drop(normal_train.index)

normal_test   = remaining_normal.sample(n=675, random_state=42)
normal_val    = remaining_normal.drop(normal_test.index).sample(n=675, random_state=42)

# %%
# -------------------------------
# Abnormal splits
# -------------------------------
ab_train  = df_abnormal.sample(n=3076, random_state=42)
remaining_ab = df_abnormal.drop(ab_train.index)

ab_test   = remaining_ab.sample(n=659, random_state=42)
ab_val    = remaining_ab.drop(ab_test.index).sample(n=659, random_state=42)

# %%
# -------------------------------
# Build final dataframes
# -------------------------------
train_df = pd.concat([normal_train, ab_train]).sample(frac=1, random_state=42)
test_df  = pd.concat([normal_test, ab_test]).sample(frac=1, random_state=42)
val_df   = pd.concat([normal_val, ab_val]).sample(frac=1, random_state=42)

# -------------------------------
# Save to CSV
# -------------------------------
train_df.to_csv("/home/jupyter-nafisha/X-ray/CSVs/train.csv", index=False)
test_df.to_csv("/home/jupyter-nafisha/X-ray/CSVs/test.csv", index=False)
val_df.to_csv("/home/jupyter-nafisha/X-ray/CSVs/validation.csv", index=False)

print("Saved train.csv, test.csv, validation.csv")
# Out:
# Saved train.csv, test.csv, validation.csv

# %%
# val_df[val_df['label'] == "Normal"]
val_df[val_df['label'] == "Abnormal"]
# Out:
#                               image_id  \
# 5726  5bb68aea19f6eb00d28d0e6386afecfc
# 5663  74292e695d6b5868b89acf26363ee93e
# 6570  7d746268923b15615c93334eff3a6baf
# 1789  c50bb66530634bfac9d5487a607e8211
# 1730  18e91ea53a6b6829c70ae2d762605c21
# ...                                ...
# 3784  aae8f5574784d4343ab50b4f0cef671d
# 5271  7d3e79d32d233140b7e30880739a42c4
# 6471  23d1c67775a1f20404642b6086b74cc8
# 3136  13088cbf40717bace59ef0961554c08f
# 3487  96c522f25fae304c496697b220be49a6
#
#                                              class_name     label
# 5726  Aortic enlargement, Consolidation, Lung Opacit...  Abnormal
# 5663  Aortic enlargement, Cardiomegaly, Lung Opacity...  Abnormal
# 6570                                   ILD, Nodule/Mass  Abnormal
# 1789                     Lung Opacity, Pleural effusion  Abnormal
# 1730                   Aortic enlargement, Cardiomegaly  Abnormal
# ...                                                 ...       ...
# 3784                   Aortic enlargement, Cardiomegaly  Abnormal
# 5271  Aortic enlargement, Cardiomegaly, Lung Opacity...  Abnormal
# 6471  Aortic enlargement, Calcification, Pleural eff...  Abnormal
# 3136  Other lesion, Pleural effusion, Pleural thicke...  Abnormal
# 3487                                 Pulmonary fibrosis  Abnormal
#
# [659 rows x 3 columns]

# %% [markdown]
# # chexpert CSV for AP inference

# %%
path= '/home/jupyter-nafisha/X-ray/CSVs/chexpert_orig.csv'

# %%
import pandas as pd
data= pd.read_csv(path)

# %%
# only frontal x ray
data = data[data['Frontal/Lateral']=='Frontal']

# %%
# only AP orientation
data = data[data['AP/PA']=='AP']

# %%
# no support device as training data has very few supporting devices
data = data[data['Support Devices']==0]

# %%
data= data.drop(columns=['Support Devices'])

# %%
import pandas as pd
import numpy as np

columns = [
    'No Finding', 'Enlarged Cardiomediastinum', 'Cardiomegaly',
    'Lung Opacity', 'Lung Lesion', 'Edema', 'Consolidation',
    'Pneumonia', 'Atelectasis', 'Pneumothorax',
    'Pleural Effusion', 'Pleural Other', 'Fracture'
]

data['class_name'] = (
    data[columns]
    .eq(1)
    .apply(lambda row: ', '.join(row.index[row]), axis=1)
)

# %%
filtered_data = data[['Path', 'class_name']]

# %%
filtered_data['label'] = np.where(
    filtered_data['class_name'] == 'No Finding',
    'Normal',
    'Abnormal'
)
# Out:
# /tmp/ipykernel_324643/676560327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['label'] = np.where(

# %%
filtered_data = filtered_data[
    filtered_data['class_name'].notna() &
    (filtered_data['class_name'].str.strip() != '')
]

# %%
filtered_data
# Out:
#                                          Path  \
# 54      patient00019/study4/view1_frontal.jpg
# 56      patient00019/study2/view1_frontal.jpg
# 119     patient00039/study3/view1_frontal.jpg
# 156     patient00048/study1/view1_frontal.jpg
# 194     patient00062/study2/view1_frontal.jpg
# ...                                       ...
# 223233  patient64381/study1/view1_frontal.jpg
# 223269  patient64414/study1/view1_frontal.jpg
# 223375  patient64507/study1/view1_frontal.jpg
# 223391  patient64522/study1/view1_frontal.jpg
# 223412  patient64539/study1/view1_frontal.jpg
#
#                                                class_name     label
# 54      Cardiomegaly, Lung Opacity, Lung Lesion, Atele...  Abnormal
# 56                              Lung Opacity, Lung Lesion  Abnormal
# 119                   Atelectasis, Pneumothorax, Fracture  Abnormal
# 156                                          Pneumothorax  Abnormal
# 194                         Atelectasis, Pleural Effusion  Abnormal
# ...                                                   ...       ...
# 223233                                   Pleural Effusion  Abnormal
# 223269                     Lung Opacity, Pleural Effusion  Abnormal
# 223375       Lung Opacity, Pneumothorax, Pleural Effusion  Abnormal
# 223391                                         No Finding    Normal
# 223412            Cardiomegaly, Lung Opacity, Atelectasis  Abnormal
#
# [4369 rows x 3 columns]

# %%
filtered_data['Path'] = filtered_data['Path'].str.replace('CheXpert-v1.0-small/train/', '')

# %%
filtered_data[filtered_data['label']=='Abnormal']
# Out:
#                                          Path  \
# 54      patient00019/study4/view1_frontal.jpg
# 56      patient00019/study2/view1_frontal.jpg
# 119     patient00039/study3/view1_frontal.jpg
# 156     patient00048/study1/view1_frontal.jpg
# 194     patient00062/study2/view1_frontal.jpg
# ...                                       ...
# 223203  patient64353/study1/view1_frontal.jpg
# 223233  patient64381/study1/view1_frontal.jpg
# 223269  patient64414/study1/view1_frontal.jpg
# 223375  patient64507/study1/view1_frontal.jpg
# 223412  patient64539/study1/view1_frontal.jpg
#
#                                                class_name     label
# 54      Cardiomegaly, Lung Opacity, Lung Lesion, Atele...  Abnormal
# 56                              Lung Opacity, Lung Lesion  Abnormal
# 119                   Atelectasis, Pneumothorax, Fracture  Abnormal
# 156                                          Pneumothorax  Abnormal
# 194                         Atelectasis, Pleural Effusion  Abnormal
# ...                                                   ...       ...
# 223203                            Edema, Pleural Effusion  Abnormal
# 223233                                   Pleural Effusion  Abnormal
# 223269                     Lung Opacity, Pleural Effusion  Abnormal
# 223375       Lung Opacity, Pneumothorax, Pleural Effusion  Abnormal
# 223412            Cardiomegaly, Lung Opacity, Atelectasis  Abnormal
#
# [3947 rows x 3 columns]

# %%
filtered_data.to_csv('/home/jupyter-nafisha/X-ray/CSVs/chexpert_AP.csv', index= False)

# %% [markdown]
# # chexpert training

# %%
path= '/home/jupyter-nafisha/X-ray/CSVs/chexpert_orig.csv'

# %%
import pandas as pd
data= pd.read_csv(path)

# %%
# only frontal x ray
data = data[data['Frontal/Lateral']=='Frontal']

# %%
# only AP orientation
data = data[data['AP/PA']=='PA']

# %%
import pandas as pd
import numpy as np

columns = [
    'No Finding', 'Enlarged Cardiomediastinum', 'Cardiomegaly',
    'Lung Opacity', 'Lung Lesion', 'Edema', 'Consolidation',
    'Pneumonia', 'Atelectasis', 'Pneumothorax',
    'Pleural Effusion', 'Pleural Other', 'Fracture'
]

data['class_name'] = (
    data[columns]
    .eq(1)
    .apply(lambda row: ', '.join(row.index[row]), axis=1)
)

# %%
data[data['class_name'] == '']
# data
# Out:
#                                                      Path     Sex  Age  \
# 20      CheXpert-v1.0-small/train/patient00011/study13...  Female   22
# 36      CheXpert-v1.0-small/train/patient00012/study2/...  Female   55
# 38      CheXpert-v1.0-small/train/patient00012/study1/...  Female   55
# 42      CheXpert-v1.0-small/train/patient00014/study1/...  Female   43
# 93      CheXpert-v1.0-small/train/patient00028/study1/...    Male   70
# ...                                                   ...     ...  ...
# 143932  CheXpert-v1.0-small/train/patient34586/study2/...    Male   81
# 143944  CheXpert-v1.0-small/train/patient34589/study1/...  Female   77
# 143948  CheXpert-v1.0-small/train/patient34590/study1/...    Male   79
# 143953  CheXpert-v1.0-small/train/patient34592/study1/...  Female   68
# 214290  CheXpert-v1.0-small/train/patient57768/study2/...  Female   63
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 20             Frontal    PA         NaN                         0.0
# 36             Frontal    PA         NaN                        -1.0
# 38             Frontal    PA         NaN                         0.0
# 42             Frontal    PA         NaN                        -1.0
# 93             Frontal    PA         NaN                         0.0
# ...                ...   ...         ...                         ...
# 143932         Frontal    PA         NaN                         0.0
# 143944         Frontal    PA         NaN                        -1.0
# 143948         Frontal    PA         NaN                         NaN
# 143953         Frontal    PA         NaN                         0.0
# 214290         Frontal    PA         NaN                         NaN
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  Edema  Consolidation  \
# 20               NaN           NaN          NaN    NaN            0.0
# 36              -1.0           0.0          NaN    NaN            0.0
# 38               NaN           NaN          NaN    NaN            NaN
# 42               NaN           0.0          NaN    NaN            NaN
# 93               NaN          -1.0          NaN    NaN            0.0
# ...              ...           ...          ...    ...            ...
# 143932           NaN           NaN         -1.0    NaN           -1.0
# 143944           NaN           NaN          NaN    0.0            0.0
# 143948           NaN          -1.0          NaN    NaN            0.0
# 143953           0.0           NaN          NaN    NaN            0.0
# 214290           NaN           0.0          NaN    NaN            NaN
#
#         Pneumonia  Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  \
# 20            NaN          0.0           0.0               0.0            NaN
# 36            NaN          NaN           NaN               0.0            NaN
# 38            NaN          NaN           NaN               0.0            NaN
# 42            NaN          NaN           0.0               0.0            NaN
# 93            NaN         -1.0           0.0               0.0            NaN
# ...           ...          ...           ...               ...            ...
# 143932        NaN          NaN           0.0               NaN            NaN
# 143944        NaN          NaN           0.0               0.0            NaN
# 143948        NaN         -1.0           NaN               NaN            NaN
# 143953        NaN          NaN           NaN               0.0            NaN
# 214290        NaN          NaN           NaN               0.0            NaN
#
#         Fracture  Support Devices class_name
# 20           NaN              NaN
# 36           NaN              1.0
# 38           NaN              1.0
# 42           NaN              NaN
# 93           NaN              NaN
# ...          ...              ...        ...
# 143932       NaN              NaN
# 143944       NaN              NaN
# 143948       NaN              NaN
# 143953       NaN              NaN
# 214290       NaN              NaN
#
# [4091 rows x 20 columns]

# %%
filtered_data = data[['Path', 'Support Devices', 'class_name']]

# %%
filtered_data['label'] = np.where(
    filtered_data['class_name'] == 'No Finding',
    'Normal',
    'Abnormal'
)
# Out:
# /tmp/ipykernel_324643/676560327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['label'] = np.where(

# %%
filtered_data = filtered_data[
    filtered_data['class_name'].notna() &
    (filtered_data['class_name'].str.strip() != '')
]

# %%
normal_df = filtered_data[filtered_data['label'] == 'Normal']
abnormal_df = filtered_data[filtered_data['label'] == 'Abnormal']

# %%
abnormal_df = abnormal_df[abnormal_df['Support Devices'] == 1]

# %%
balanced_df = pd.concat([normal_df, abnormal_df]) \
                 .sample(frac=1, random_state=42) \
                 .reset_index(drop=True)

# %%
balanced_df
# Out:
#                                         Path  Support Devices  \
# 0      patient23492/study1/view1_frontal.jpg              NaN
# 1      patient04539/study1/view1_frontal.jpg              1.0
# 2      patient05896/study1/view1_frontal.jpg              NaN
# 3      patient00901/study1/view1_frontal.jpg              NaN
# 4      patient16014/study8/view1_frontal.jpg              1.0
# ...                                      ...              ...
# 11161  patient01622/study2/view1_frontal.jpg              1.0
# 11162  patient32632/study2/view1_frontal.jpg              1.0
# 11163  patient33895/study1/view1_frontal.jpg              NaN
# 11164  patient05453/study1/view2_frontal.jpg              NaN
# 11165  patient11149/study1/view1_frontal.jpg              1.0
#
#                                               class_name     label
# 0                                             No Finding    Normal
# 1                              Lung Opacity, Lung Lesion  Abnormal
# 2                                             No Finding    Normal
# 3                                             No Finding    Normal
# 4               Lung Opacity, Atelectasis, Pleural Other  Abnormal
# ...                                                  ...       ...
# 11161                                       Cardiomegaly  Abnormal
# 11162                                         No Finding    Normal
# 11163                                         No Finding    Normal
# 11164                                         No Finding    Normal
# 11165  Enlarged Cardiomediastinum, Lung Opacity, Edem...  Abnormal
#
# [11166 rows x 4 columns]

# %%
balanced_df['Path'] = balanced_df['Path'].str.replace('CheXpert-v1.0-small/train/', '')

# %%
balanced_df.to_csv('/home/jupyter-nafisha/X-ray/CSVs/chexpert_PA.csv', index= False)

# %% [markdown]
# ### train test and validation split

# %%
import pandas as pd
df = pd.read_csv('/home/jupyter-nafisha/X-ray/CSVs/chexpert_PA.csv')

# %%
df= df.drop(columns=['Support Devices'])

# %%
df = df.rename(columns={'Path': 'image_id'})

# %%
# Split into normal and abnormal
df_normal = df[df["label"] == "Normal"]
df_abnormal = df[df["label"] == "Abnormal"]

print("Normal:", len(df_normal))
print("Abnormal:", len(df_abnormal))
# Out:
# Normal: 5499
# Abnormal: 5667

# %%
# -------------------------------
# Normal splits
# -------------------------------
normal_train  = df_normal.sample(n=3849, random_state=42)
remaining_normal = df_normal.drop(normal_train.index)

normal_test   = remaining_normal.sample(n=825, random_state=42)
normal_val    = remaining_normal.drop(normal_test.index).sample(n=825, random_state=42)

# %%
# -------------------------------
# Abnormal splits
# -------------------------------
ab_train  = df_abnormal.sample(n=3967, random_state=42)
remaining_ab = df_abnormal.drop(ab_train.index)

ab_test   = remaining_ab.sample(n=850, random_state=42)
ab_val    = remaining_ab.drop(ab_test.index).sample(n=850, random_state=42)

# %%
# -------------------------------
# Build final dataframes
# -------------------------------
train_df = pd.concat([normal_train, ab_train]).sample(frac=1, random_state=42)
test_df  = pd.concat([normal_test, ab_test]).sample(frac=1, random_state=42)
val_df   = pd.concat([normal_val, ab_val]).sample(frac=1, random_state=42)

# -------------------------------
# Save to CSV
# -------------------------------
train_df.to_csv("/home/jupyter-nafisha/X-ray/CSVs/train_chex.csv", index=False)
test_df.to_csv("/home/jupyter-nafisha/X-ray/CSVs/test_chex.csv", index=False)
val_df.to_csv("/home/jupyter-nafisha/X-ray/CSVs/validation_chex.csv", index=False)

print("Saved train.csv, test.csv, validation.csv")
# Out:
# Saved train.csv, test.csv, validation.csv

# %% [markdown]
# ### combining CSVs

# %%
# Train CSV

chex_train = '/home/jupyter-nafisha/X-ray/CSVs/train_chex.csv'
vin_train= '/home/jupyter-nafisha/X-ray/CSVs/train.csv'

chex= pd.read_csv(chex_train)
vin= pd.read_csv(vin_train)

chex['image_id'] = 'chexpert_PA/' + chex['image_id']
vin['image_id'] = 'Xray-Data/' + vin['image_id']

chex.to_csv(chex_train, index=False)
vin.to_csv(vin_train, index=False)

combined_df = pd.concat([chex, vin], ignore_index=True)
combined_df.to_csv('/home/jupyter-nafisha/X-ray/CSVs/train_combined.csv', index=False)

# %%
# Validation CSV

chex_valid = '/home/jupyter-nafisha/X-ray/CSVs/validation_chex.csv'
vin_valid= '/home/jupyter-nafisha/X-ray/CSVs/validation.csv'

chex= pd.read_csv(chex_valid)
vin= pd.read_csv(vin_valid)

chex['image_id'] = 'chexpert_PA/' + chex['image_id']
vin['image_id'] = 'Xray-Data/' + vin['image_id']

chex.to_csv(chex_valid, index=False)
vin.to_csv(vin_valid, index=False)

combined_df = pd.concat([chex, vin], ignore_index=True)
combined_df.to_csv('/home/jupyter-nafisha/X-ray/CSVs/valid_combined.csv', index=False)

# %%
# Test CSV

chex_test = '/home/jupyter-nafisha/X-ray/CSVs/test_chex.csv'
vin_test= '/home/jupyter-nafisha/X-ray/CSVs/test.csv'

chex= pd.read_csv(chex_test)
vin= pd.read_csv(vin_test)

chex['image_id'] = 'chexpert_PA/' + chex['image_id']
vin['image_id'] = 'Xray-Data/' + vin['image_id']

chex.to_csv(chex_test, index=False)
vin.to_csv(vin_test, index=False)

combined_df = pd.concat([chex, vin], ignore_index=True)
combined_df.to_csv('/home/jupyter-nafisha/X-ray/CSVs/test_combined.csv', index=False)

# %%
path= '/home/jupyter-nafisha/X-ray/CSVs/train_combined.csv'
path= '/home/jupyter-nafisha/X-ray/CSVs/valid_combined.csv'
path= '/home/jupyter-nafisha/X-ray/CSVs/test_combined.csv'

count=0
data= pd.read_csv(path)
for _, row in data.iterrows():
    new_path= os.path.join('/home/common', row['image_id'])
    if not os.path.exists(new_path):
        count+=1
        # print(new_path)
count
# Out:
# 0

# %%
len(data[data['label']=='Normal']), len(data[data['label']=='Abnormal'])
# Out:
# (1500, 1509)

# %% [markdown]
# # NIH testing data

# %%
import pandas as pd
path= '/home/jupyter-nafisha/X-ray/CSVs/NIH_orig.csv'
data = pd.read_csv(path)
data
# Out:
#              Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0       00000001_000.png            Cardiomegaly            0           1
# 1       00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2       00000001_002.png   Cardiomegaly|Effusion            2           1
# 3       00000002_000.png              No Finding            0           2
# 4       00000003_000.png                  Hernia            0           3
# ...                  ...                     ...          ...         ...
# 112115  00030801_001.png          Mass|Pneumonia            1       30801
# 112116  00030802_000.png              No Finding            0       30802
# 112117  00030803_000.png              No Finding            0       30803
# 112118  00030804_000.png              No Finding            0       30804
# 112119  00030805_000.png              No Finding            0       30805
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# 0                58              M            PA                 2682
# 1                58              M            PA                 2894
# 2                58              M            PA                 2500
# 3                81              M            PA                 2500
# 4                81              F            PA                 2582
# ...             ...            ...           ...                  ...
# 112115           39              M            PA                 2048
# 112116           29              M            PA                 2048
# 112117           42              F            PA                 2048
# 112118           30              F            PA                 2048
# 112119           27              M            PA                 2048
#
#         Height]  OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 0          2749                        0.143  0.143          NaN
# 1          2729                        0.143  0.143          NaN
# 2          2048                        0.168  0.168          NaN
# 3          2048                        0.171  0.171          NaN
# 4          2991                        0.143  0.143          NaN
# ...         ...                          ...    ...          ...
# 112115     2500                        0.168  0.168          NaN
# 112116     2500                        0.168  0.168          NaN
# 112117     2500                        0.168  0.168          NaN
# 112118     2500                        0.168  0.168          NaN
# 112119     2500                        0.171  0.171          NaN
#
# [112120 rows x 12 columns]

# %%
data= data[data['View Position']=='PA']

# %%
data
# Out:
#              Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0       00000001_000.png            Cardiomegaly            0           1
# 1       00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2       00000001_002.png   Cardiomegaly|Effusion            2           1
# 3       00000002_000.png              No Finding            0           2
# 4       00000003_000.png                  Hernia            0           3
# ...                  ...                     ...          ...         ...
# 112115  00030801_001.png          Mass|Pneumonia            1       30801
# 112116  00030802_000.png              No Finding            0       30802
# 112117  00030803_000.png              No Finding            0       30803
# 112118  00030804_000.png              No Finding            0       30804
# 112119  00030805_000.png              No Finding            0       30805
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# 0                58              M            PA                 2682
# 1                58              M            PA                 2894
# 2                58              M            PA                 2500
# 3                81              M            PA                 2500
# 4                81              F            PA                 2582
# ...             ...            ...           ...                  ...
# 112115           39              M            PA                 2048
# 112116           29              M            PA                 2048
# 112117           42              F            PA                 2048
# 112118           30              F            PA                 2048
# 112119           27              M            PA                 2048
#
#         Height]  OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 0          2749                        0.143  0.143          NaN
# 1          2729                        0.143  0.143          NaN
# 2          2048                        0.168  0.168          NaN
# 3          2048                        0.171  0.171          NaN
# 4          2991                        0.143  0.143          NaN
# ...         ...                          ...    ...          ...
# 112115     2500                        0.168  0.168          NaN
# 112116     2500                        0.168  0.168          NaN
# 112117     2500                        0.168  0.168          NaN
# 112118     2500                        0.168  0.168          NaN
# 112119     2500                        0.171  0.171          NaN
#
# [67310 rows x 12 columns]

# %%
filtered_data= data[['Image Index', 'Finding Labels']]

# %%
filtered_data = filtered_data.rename(columns={
    'Image Index': 'image_id', 
    'Finding Labels': 'class_name'                     
})

# %%
filtered_data['label'] = np.where(
    filtered_data['class_name'] == 'No Finding',
    'Normal',
    'Abnormal'
)

# %%
normal_df = filtered_data[filtered_data['label']=='Normal'].iloc[0:500]
abnormal_df = filtered_data[filtered_data['label']=='Abnormal'].iloc[0:500]

# %%
normal_df
# Out:
#               image_id  class_name   label
# 3     00000002_000.png  No Finding  Normal
# 13    00000005_000.png  No Finding  Normal
# 16    00000005_003.png  No Finding  Normal
# 17    00000005_004.png  No Finding  Normal
# 18    00000005_005.png  No Finding  Normal
# ...                ...         ...     ...
# 1414  00000370_005.png  No Finding  Normal
# 1416  00000370_007.png  No Finding  Normal
# 1418  00000370_009.png  No Finding  Normal
# 1421  00000371_000.png  No Finding  Normal
# 1428  00000372_006.png  No Finding  Normal
#
# [500 rows x 3 columns]

# %%
combined_testSet = (
    pd.concat([normal_df, abnormal_df], ignore_index=True)
      .sample(frac=1, random_state=42)
      .reset_index(drop=True)
)

# %%
combined_testSet
# Out:
#              image_id    class_name     label
# 0    00000013_020.png  Pneumothorax  Abnormal
# 1    00000174_005.png        Nodule  Abnormal
# 2    00000178_000.png  Infiltration  Abnormal
# 3    00000105_004.png        Nodule  Abnormal
# 4    00000318_001.png    No Finding    Normal
# ..                ...           ...       ...
# 995  00000100_001.png    No Finding    Normal
# 996  00000223_000.png    No Finding    Normal
# 997  00000277_001.png  Infiltration  Abnormal
# 998  00000327_001.png    No Finding    Normal
# 999  00000095_000.png    No Finding    Normal
#
# [1000 rows x 3 columns]

# %%
combined_testSet.to_csv('/home/jupyter-nafisha/X-ray/CSVs/NIH_test.csv', index= False)

# %%
len(os.listdir('/home/jupyter-nafisha/X-ray/Inference_data/NIH-test-dataset'))
# Out:
# 1000
